# %%
# HQCCNN_Fashion-MNIST_10000
train_loss_11=[1.665521183013916, 1.0257362270355224, 0.8430974337259929, 0.7514805075327555, 0.6891647166411082, 0.6462073492209116, 0.6066805497805278, 0.5675647721290589, 0.5218466855684916, 0.4862496661345164, 0.46052114272117617, 0.439852624018987, 0.4196079982916514, 0.4029664259751638, 0.3962772445678711, 0.37799072329203287, 0.36780275575319926, 0.36254378537336984, 0.35255603249867756, 0.34516377027829487, 0.3447720606327057, 0.34326804741223654, 0.32859994180997215, 0.3138159209092458, 0.3163094528516134, 0.31290006045500435, 0.30557621296246845, 0.30389477507273355, 0.2961399755080541, 0.2899386016527812, 0.28481180787086485, 0.28208358502388, 0.2775517613887787, 0.27566811990737916, 0.27750876907507577, 0.27996682476997375, 0.2799581191937129, 0.2569213434855143, 0.2895033198197683, 0.27591254842281343, 0.2559866916338603, 0.2625649842818578, 0.24994948661327362, 0.24492054458459217, 0.24501412093639374, 0.2590239917039871, 0.2522851105133692, 0.24591200850407283, 0.24577865207195282, 0.2582484496831894]
valid_loss_11=[1.173177041053772, 0.9237695951461792, 0.8050244355201721, 0.7480952053070068, 0.6896926145553589, 0.6633772234916687, 0.652800064086914, 0.5951936535835266, 0.5790472936630249, 0.5677333176136017, 0.5666035475730896, 0.5137440638542176, 0.4974163064956665, 0.4885325703620911, 0.5070415101051331, 0.5021575541496277, 0.4822568619251251, 0.49309365940093997, 0.482873340845108, 0.5226585764884949, 0.4656093647480011, 0.47621073842048645, 0.4411702167987823, 0.48118918371200564, 0.4428318076133728, 0.45825227117538453, 0.4520439186096191, 0.5619688639640809, 0.4598085310459137, 0.4520720338821411, 0.4431749310493469, 0.43896634674072266, 0.45366859197616577, 0.46818410110473635, 0.46225513792037964, 0.46404233169555664, 0.4460744013786316, 0.44678385615348815, 0.45245514178276064, 0.4481102113723755, 0.4523086843490601, 0.456927300453186, 0.44307320833206176, 0.43986661815643313, 0.4440807547569275, 0.4292193877696991, 0.4751128125190735, 0.4537644810676575, 0.44481298756599424, 0.4574345562458038]
train_acc_11=[0.5226666666666666, 0.6728333333333333, 0.7083333333333334, 0.7311666666666666, 0.7423333333333333, 0.7743333333333333, 0.8046666666666666, 0.8315, 0.8396666666666667, 0.8548333333333333, 0.864, 0.8676666666666667, 0.8713333333333333, 0.8753333333333333, 0.8766666666666667, 0.8825, 0.8881666666666667, 0.885, 0.8901666666666667, 0.8913333333333333, 0.89, 0.8916666666666667, 0.8941666666666667, 0.9028333333333334, 0.9008333333333334, 0.9023333333333333, 0.9051666666666667, 0.9015, 0.9021666666666667, 0.908, 0.9095, 0.912, 0.9133333333333333, 0.9136666666666666, 0.9096666666666666, 0.9108333333333334, 0.9096666666666666, 0.9216666666666666, 0.9071666666666667, 0.9108333333333334, 0.9163333333333333, 0.9165, 0.9208333333333333, 0.9243333333333333, 0.9201666666666667, 0.9218333333333333, 0.918, 0.9226666666666666, 0.9215, 0.9168333333333333]
valid_acc_11=[0.6545, 0.681, 0.7085, 0.6975, 0.7565, 0.776, 0.805, 0.8275, 0.8115, 0.8285, 0.8065, 0.8415, 0.829, 0.8415, 0.8355, 0.826, 0.836, 0.839, 0.848, 0.817, 0.842, 0.837, 0.85, 0.8295, 0.8545, 0.85, 0.85, 0.801, 0.8445, 0.841, 0.8495, 0.848, 0.8355, 0.8445, 0.842, 0.845, 0.848, 0.838, 0.849, 0.8455, 0.8365, 0.837, 0.8455, 0.853, 0.853, 0.8525, 0.8425, 0.841, 0.8435, 0.8415]

# TL-HQCCNN_Fashion-MNIST_10000
train_loss_12=[1.8579373658498128, 1.1952324511210124, 0.9443395349184672, 0.837266154607137, 0.7543495707511901, 0.6913152287801106, 0.6482657066980998, 0.6017130303382874, 0.5763081501324971, 0.5478136115074158, 0.5459360256195068, 0.5258499477704366, 0.505612015247345, 0.489309671719869, 0.472927214940389, 0.46812249302864073, 0.4502384849389394, 0.42400846513112384, 0.4253429461320241, 0.41424736253420513, 0.4192910193602244, 0.4128976763089498, 0.394380939801534, 0.4208516409397125, 0.40255294521649676, 0.39015645599365234, 0.3781464498837789, 0.3855964118639628, 0.3750396562417348, 0.3865483594735463, 0.3756872243881226, 0.3857260173956553, 0.38568438482284545, 0.3719594355424245, 0.3781774762471517, 0.3727016747792562, 0.381861495812734, 0.3772991584936778, 0.36529279176394147, 0.37796519017219543, 0.3746343777974447, 0.35469879881540933, 0.3571071054935455, 0.3745288679599762, 0.36823707167307534, 0.37294289135932923, 0.35203179756800335, 0.36141866993904115, 0.3495774571498235, 0.33866542593638105]
valid_loss_12=[1.4031279783248902, 0.9985848846435547, 0.8529191565513611, 0.7743310194015502, 0.7294001450538635, 0.6980237545967102, 0.6339371576309204, 0.6041704983711242, 0.605574660539627, 0.6126904697418213, 0.574297562122345, 0.5406019248962403, 0.542557137966156, 0.5523521869182587, 0.5315000336170197, 0.5071327278614044, 0.48928803062438964, 0.4871939604282379, 0.5165368552207947, 0.48505888748168946, 0.5019311027526856, 0.48565185809135436, 0.5405607380867005, 0.48479200077056883, 0.47426030135154723, 0.4720182921886444, 0.5045389313697815, 0.46471040678024295, 0.4722133362293243, 0.4896376504898071, 0.5029590747356415, 0.4684610285758972, 0.48122744703292847, 0.46230974125862123, 0.471785590171814, 0.4908768845796585, 0.453983713388443, 0.4609694736003876, 0.4762834048271179, 0.4764206323623657, 0.4694814338684082, 0.4898142137527466, 0.4971167702674866, 0.46775923919677737, 0.47475864720344546, 0.45583016777038576, 0.4671722240447998, 0.462266592502594, 0.4423974297046661, 0.4654387586116791]
train_acc_12=[0.4781666666666667, 0.6871666666666667, 0.7495, 0.7751666666666667, 0.7903333333333333, 0.7996666666666666, 0.8093333333333333, 0.8206666666666667, 0.8298333333333333, 0.8363333333333334, 0.8376666666666667, 0.846, 0.8503333333333334, 0.8601666666666666, 0.8583333333333333, 0.8595, 0.8681666666666666, 0.8721666666666666, 0.8723333333333333, 0.8738333333333334, 0.8723333333333333, 0.8728333333333333, 0.877, 0.8686666666666667, 0.8801666666666667, 0.8793333333333333, 0.8825, 0.8816666666666667, 0.884, 0.8845, 0.887, 0.879, 0.8823333333333333, 0.891, 0.8896666666666667, 0.89, 0.8855, 0.8833333333333333, 0.8876666666666667, 0.8923333333333333, 0.8866666666666667, 0.8911666666666667, 0.8896666666666667, 0.8881666666666667, 0.888, 0.8858333333333334, 0.892, 0.8898333333333334, 0.8948333333333334, 0.9008333333333334]
valid_acc_12=[0.6685, 0.7385, 0.7545, 0.7625, 0.7865, 0.788, 0.807, 0.8075, 0.8165, 0.8105, 0.828, 0.836, 0.8365, 0.83, 0.8405, 0.84, 0.8425, 0.8415, 0.839, 0.8435, 0.8355, 0.8395, 0.82, 0.84, 0.849, 0.8495, 0.836, 0.8465, 0.845, 0.846, 0.8275, 0.8405, 0.84, 0.846, 0.836, 0.8395, 0.842, 0.8465, 0.8425, 0.8455, 0.846, 0.836, 0.8325, 0.8465, 0.8385, 0.848, 0.837, 0.837, 0.856, 0.84]

# ST-HQCCNN_Fashion-MNIST_10000
train_loss_13=[0.9121681842803955, 0.5486415423552196, 0.45668375364939373, 0.41437207579612734, 0.3866357009410858, 0.36562926332155865, 0.34842657176653546, 0.33139792490005493, 0.309881204922994, 0.29781888429323833, 0.286453489224116, 0.2781937744617462, 0.26410503800710045, 0.25410143264134727, 0.25257590277989705, 0.24720121562480926, 0.24870306448141735, 0.23739417640368143, 0.2381287403901418, 0.23237928104400635, 0.22958948095639548, 0.22173703209559123, 0.22464717757701874, 0.22620209610462189, 0.21614145135879517, 0.2157827854156494, 0.2085802140235901, 0.20932303063074748, 0.21075636116663615, 0.20251371391614278, 0.20483586700757345, 0.20202284276485444, 0.20095986437797547, 0.20202970480918883, 0.1924924834171931, 0.200144160370032, 0.19880216681957244, 0.190357342282931, 0.1860081564982732, 0.18835279856125514, 0.18880157121022542, 0.1862328867117564, 0.18118554790814717, 0.1812922227581342, 0.17843728323777516, 0.18254409756263096, 0.1841430085102717, 0.17740671082337697, 0.17647702554861705, 0.17677201855182648]
valid_loss_13=[1.15208154296875, 0.8939278516769409, 0.8067912912368774, 0.7454653670787811, 0.6973846979141235, 0.6779265871047974, 0.6452112464904786, 0.6293646554946899, 0.5911484026908874, 0.5747679500579834, 0.5691878848075866, 0.5431255602836609, 0.5705091791152954, 0.5105509190559387, 0.566887086391449, 0.49721826815605163, 0.5119632196426391, 0.48425980377197264, 0.545016161084175, 0.5145540330410003, 0.504861734509468, 0.47425138211250306, 0.4774927864074707, 0.5428114347457885, 0.47246430015563967, 0.4698497462272644, 0.48176578402519227, 0.5062560276985169, 0.4928536841869354, 0.46909715938568114, 0.4657472012042999, 0.48661559748649597, 0.48886683106422424, 0.45032699847221375, 0.49752701687812806, 0.45150991225242615, 0.4582852418422699, 0.4494716076850891, 0.42747397875785825, 0.4657519540786743, 0.4685471959114075, 0.4648817141056061, 0.49128948712348935, 0.44980856704711913, 0.454124115228653, 0.49040661215782166, 0.4580880630016327, 0.44820986104011534, 0.4457554769515991, 0.460826411485672]
train_acc_13=[0.47733333333333333, 0.669, 0.7093333333333334, 0.7291666666666666, 0.7451666666666666, 0.7675, 0.7963333333333333, 0.8145, 0.8378333333333333, 0.8383333333333334, 0.8451666666666666, 0.8491666666666666, 0.8561666666666666, 0.8658333333333333, 0.8653333333333333, 0.8658333333333333, 0.8625, 0.8738333333333334, 0.8666666666666667, 0.8736666666666667, 0.8745, 0.8826666666666667, 0.876, 0.8743333333333333, 0.8791666666666667, 0.8826666666666667, 0.8865, 0.8843333333333333, 0.8868333333333334, 0.893, 0.889, 0.89, 0.8906666666666667, 0.8936666666666667, 0.8961666666666667, 0.891, 0.8875, 0.9023333333333333, 0.9001666666666667, 0.8991666666666667, 0.896, 0.8991666666666667, 0.9013333333333333, 0.9015, 0.9045, 0.8965, 0.8998333333333334, 0.9046666666666666, 0.9061666666666667, 0.9061666666666667]
valid_acc_13=[0.6375, 0.673, 0.7185, 0.7235, 0.736, 0.766, 0.789, 0.809, 0.817, 0.816, 0.816, 0.83, 0.823, 0.8275, 0.8125, 0.842, 0.8215, 0.842, 0.8275, 0.825, 0.8285, 0.839, 0.8385, 0.816, 0.8435, 0.8445, 0.846, 0.838, 0.832, 0.8335, 0.851, 0.827, 0.826, 0.8505, 0.831, 0.8515, 0.8485, 0.8535, 0.8575, 0.8495, 0.842, 0.851, 0.838, 0.8395, 0.834, 0.823, 0.8385, 0.8445, 0.842, 0.8375]

# %%
# HQCCNN_Fashion-MNIST_5000
train_loss_21=[1.9215725495020548, 1.3599570153554281, 1.0859049560228984, 0.9437903838157654, 0.8560170046488444, 0.7994005525906881, 0.7420219209988912, 0.7037190664609273, 0.6675060181617737, 0.6342488179206848, 0.6183937991460164, 0.5954636019070944, 0.5688285525639852, 0.5390758205254873, 0.5238241984844207, 0.50027308511734, 0.47161443773905437, 0.4511725056966146, 0.4292552977403005, 0.41795336906115216, 0.39768697023391725, 0.3805681169827779, 0.36395710786183677, 0.33891545673211415, 0.33591516403357186, 0.3220290227333705, 0.31956165726979574, 0.3189463882446289, 0.3026463075478872, 0.27849699815114337, 0.27875902491807936, 0.2726912197271983, 0.26971552964051565, 0.2550569314757983, 0.2571768836180369, 0.24163860003153484, 0.2284580279191335, 0.2328030995130539, 0.22116877301534016, 0.22591814947128297, 0.21965552961826323, 0.2070905556678772, 0.19937159583965938, 0.2103752993742625, 0.19878035279115042, 0.1864121290842692, 0.1966460385719935, 0.17100569212436675, 0.16996392969290416, 0.20449923598766326]
valid_loss_21=[1.5627609071731567, 1.1632345085144042, 0.9781473407745361, 0.8877167801856994, 0.8222401809692382, 0.773181930065155, 0.7404629526138305, 0.7210076394081115, 0.6794424285888672, 0.6809956254959106, 0.66834849858284, 0.6290407390594482, 0.6160953488349915, 0.599392915725708, 0.5955573248863221, 0.5847096700668335, 0.5609895279407501, 0.5510489573478698, 0.5624660110473633, 0.5291558103561401, 0.514989966392517, 0.5112419307231904, 0.510085844039917, 0.4893035478591919, 0.49990439987182617, 0.48280337524414063, 0.4786153661012649, 0.4875462460517883, 0.4488745219707489, 0.48932225036621096, 0.4738257827758789, 0.45277200078964236, 0.44900520181655884, 0.45741660809516904, 0.4448639135360718, 0.4467253692150116, 0.4544502787590027, 0.44384968757629395, 0.4340112314224243, 0.4555644598007202, 0.4377674298286438, 0.4669668345451355, 0.43972929668426514, 0.4536259660720825, 0.44020378255844117, 0.4852039861679077, 0.45676575660705565, 0.46663403224945066, 0.44334716296195986, 0.45037153816223147]
train_acc_21=[0.43400000015894574, 0.628666666507721, 0.6813333334922791, 0.7056666668256124, 0.7159999998410543, 0.7229999998410542, 0.734666666507721, 0.7623333333333333, 0.7543333333333333, 0.7896666668256124, 0.796, 0.8156666665077209, 0.8239999998410543, 0.850333333492279, 0.858, 0.870666666507721, 0.877333333492279, 0.8856666668256123, 0.8916666666666667, 0.8953333334922791, 0.8993333331743876, 0.907, 0.9130000001589457, 0.9196666666666666, 0.9153333331743876, 0.923666666507721, 0.918666666507721, 0.918, 0.9273333333333333, 0.9303333331743876, 0.932, 0.9326666665077209, 0.9320000001589457, 0.938, 0.939, 0.941, 0.9446666665077209, 0.9463333334922791, 0.9450000001589457, 0.9443333331743876, 0.9440000001589457, 0.9503333333333334, 0.9533333333333334, 0.9469999998410543, 0.9546666665077209, 0.9593333333333334, 0.9503333331743876, 0.9609999998410543, 0.9609999998410543, 0.95]
valid_acc_21=[0.602, 0.683, 0.704, 0.709, 0.716, 0.728, 0.736, 0.735, 0.75, 0.772, 0.766, 0.793, 0.815, 0.809, 0.815, 0.827, 0.828, 0.821, 0.834, 0.84, 0.841, 0.837, 0.839, 0.84, 0.836, 0.84, 0.85, 0.835, 0.851, 0.836, 0.84, 0.844, 0.846, 0.844, 0.849, 0.845, 0.852, 0.841, 0.85, 0.836, 0.867, 0.836, 0.846, 0.851, 0.849, 0.829, 0.839, 0.842, 0.847, 0.838]

# TL-HQCCNN_Fashion-MNIST_5000
train_loss_22=[2.1026992451349895, 1.6173080860773723, 1.3408461135228475, 1.1628760296503702, 1.0278650738398234, 0.9501887515385946, 0.9159856103261312, 0.8350670959154765, 0.7931274902025859, 0.7616490658124287, 0.6999045988718668, 0.6779521342913309, 0.6811448868115743, 0.6332157085736593, 0.602971847375234, 0.5941004185676575, 0.5957170144716899, 0.5600241545041402, 0.549434603770574, 0.554438116312027, 0.5131615688006084, 0.5230207765102386, 0.508584817091624, 0.5086022542317709, 0.4864532471497854, 0.45451960428555804, 0.4373866601785024, 0.42074512235323586, 0.4253659478028615, 0.4050181192557017, 0.41766436330477397, 0.4122803041934967, 0.38916272890567777, 0.3800110365549723, 0.3763161954085032, 0.3784716333548228, 0.362520312945048, 0.3516139396031698, 0.34424506131807964, 0.36906126952171325, 0.35705084896087647, 0.36405362582206724, 0.3443257296880086, 0.3450022659301758, 0.3155396523475647, 0.3145851445992788, 0.2992028532822927, 0.3206473001241684, 0.29918519632021584, 0.319799601038297]
valid_loss_22=[1.7896888332366943, 1.427913451194763, 1.2032492570877076, 1.06874658203125, 0.9781712894439697, 0.8984453349113465, 0.8611592559814453, 0.8318181233406067, 0.7667865972518921, 0.7558196797370911, 0.7361907062530517, 0.7077652010917663, 0.6718230838775635, 0.6626292448043823, 0.6377117571830749, 0.6462107663154602, 0.6445373086929321, 0.6231271362304688, 0.61018310546875, 0.6275177669525146, 0.5823796081542969, 0.5788342518806457, 0.6026392500400544, 0.5873390364646912, 0.5945161463022232, 0.5621060717105866, 0.5476270089149475, 0.5530391502380371, 0.5255672962665557, 0.5992340974807739, 0.5030808148384094, 0.5112126889228821, 0.5049025435447693, 0.5464910998344421, 0.5068431437015534, 0.5127478194236755, 0.5042232418060303, 0.49487552666664125, 0.5243965620994568, 0.4938533992767334, 0.48357259869575503, 0.4947189292907715, 0.5064074540138245, 0.49478620767593384, 0.4980325264930725, 0.47590229177474974, 0.4875878028869629, 0.4846810898780823, 0.48375008392333985, 0.49742854595184327]
train_acc_22=[0.2946666668256124, 0.581333333492279, 0.6243333331743877, 0.672666666507721, 0.7270000001589457, 0.752333333492279, 0.752333333492279, 0.7803333334922791, 0.7859999998410543, 0.7806666666666666, 0.7989999998410543, 0.8099999998410543, 0.8069999998410543, 0.8199999998410543, 0.8233333334922791, 0.8286666668256124, 0.8223333333333334, 0.8403333333333334, 0.8449999998410542, 0.8433333333333334, 0.8576666665077209, 0.8483333331743876, 0.8623333333333333, 0.8526666666666667, 0.8643333333333333, 0.867333333492279, 0.8799999998410543, 0.875, 0.883, 0.8906666668256124, 0.8816666668256123, 0.8816666666666667, 0.889666666507721, 0.8946666668256124, 0.8983333331743876, 0.8983333331743876, 0.896666666507721, 0.9033333331743876, 0.9050000001589458, 0.903, 0.901, 0.9020000001589458, 0.9053333333333333, 0.9076666668256124, 0.9193333334922791, 0.916666666507721, 0.9256666666666666, 0.9123333331743876, 0.9210000001589457, 0.9096666668256124]
valid_acc_22=[0.597, 0.646, 0.697, 0.745, 0.747, 0.775, 0.782, 0.793, 0.796, 0.795, 0.787, 0.794, 0.806, 0.801, 0.807, 0.821, 0.808, 0.816, 0.821, 0.812, 0.837, 0.83, 0.806, 0.825, 0.819, 0.83, 0.826, 0.821, 0.828, 0.818, 0.843, 0.84, 0.843, 0.82, 0.839, 0.836, 0.846, 0.845, 0.837, 0.849, 0.852, 0.839, 0.842, 0.847, 0.847, 0.839, 0.829, 0.847, 0.842, 0.844]

# ST-HQCCNN_Fashion-MNIST_5000
train_loss_23=[1.0639546950658163, 0.7529010863304139, 0.5950735975901286, 0.5209123902320861, 0.4803253446420034, 0.4468179969787598, 0.42520797618230183, 0.40946543343861896, 0.3901206100781759, 0.37816704765955605, 0.36293047428131103, 0.35427660012245177, 0.337032879114151, 0.32536694161097207, 0.3115121560096741, 0.29584796738624575, 0.279542050798734, 0.2796198344230652, 0.268356569369634, 0.2541263327598572, 0.2461226051648458, 0.24226856700579324, 0.23765966367721558, 0.2292510404586792, 0.22888358505566914, 0.22482419522603353, 0.21661487519741057, 0.21176339546839396, 0.21022402318318684, 0.20497911874453226, 0.20833563017845153, 0.20720500644048054, 0.19850291840235393, 0.18951496756076813, 0.19001448810100555, 0.18264029455184935, 0.1926799032688141, 0.18437075944741568, 0.1824755051136017, 0.18094453036785127, 0.18075361589590708, 0.1703806181748708, 0.17699195671081544, 0.17531415633360545, 0.1629665172100067, 0.1691233743230502, 0.16511016082763671, 0.17300211854775746, 0.16437782998879752, 0.1657657340168953]
valid_loss_23=[1.613006555557251, 1.1999373540878295, 0.9957527527809144, 0.892491159439087, 0.836484833240509, 0.8034772133827209, 0.7706602120399475, 0.7483589572906494, 0.7512904372215271, 0.7206187834739685, 0.7172672195434571, 0.690287236213684, 0.6534819934368133, 0.6240523314476013, 0.6232063856124878, 0.5844203639030456, 0.5796154751777649, 0.5576443810462952, 0.5468009061813355, 0.5315065565109253, 0.5286581904888153, 0.539217568397522, 0.5111392049789428, 0.4866670780181885, 0.5024532480239868, 0.4854770679473877, 0.49059143233299257, 0.4821008198261261, 0.4661124470233917, 0.4658853545188904, 0.4724888753890991, 0.48694809126853944, 0.44972293519973755, 0.44314503455162046, 0.44384716045856476, 0.45387596583366396, 0.46113244104385376, 0.450699378490448, 0.45295668542385104, 0.4714297914505005, 0.4564338595867157, 0.4815663237571716, 0.4410340256690979, 0.4330996985435486, 0.4440771988630295, 0.4292705693244934, 0.43762841427326205, 0.4390829005241394, 0.4384677243232727, 0.4724638204574585]
train_acc_23=[0.3750000000794729, 0.6126666666666667, 0.637666666507721, 0.6549999998410543, 0.6676666666666666, 0.6799999998410543, 0.6913333331743876, 0.7203333331743876, 0.722, 0.7476666668256123, 0.7849999998410543, 0.8149999998410543, 0.8263333333333334, 0.8406666668256124, 0.8530000001589457, 0.864, 0.869666666507721, 0.867666666507721, 0.8759999998410543, 0.8833333331743877, 0.8943333334922791, 0.8893333333333333, 0.8853333333333333, 0.9030000001589458, 0.8943333334922791, 0.905, 0.9066666668256124, 0.905, 0.9103333334922791, 0.9119999998410543, 0.906666666507721, 0.9080000001589458, 0.9153333334922791, 0.9206666666666666, 0.917666666507721, 0.9223333331743876, 0.9163333334922791, 0.9243333331743876, 0.9203333331743876, 0.9243333334922791, 0.9246666666666666, 0.9320000001589457, 0.9233333334922791, 0.9266666665077209, 0.9390000001589457, 0.9333333333333333, 0.9350000001589457, 0.9316666665077209, 0.9326666666666666, 0.9343333331743876]
valid_acc_23=[0.567, 0.642, 0.649, 0.658, 0.667, 0.672, 0.687, 0.676, 0.745, 0.758, 0.77, 0.806, 0.811, 0.804, 0.819, 0.837, 0.827, 0.838, 0.836, 0.842, 0.846, 0.836, 0.85, 0.845, 0.847, 0.84, 0.843, 0.843, 0.853, 0.858, 0.845, 0.841, 0.84, 0.854, 0.856, 0.849, 0.852, 0.856, 0.853, 0.848, 0.86, 0.825, 0.849, 0.851, 0.848, 0.854, 0.856, 0.849, 0.85, 0.853]

# %%
# HQCCNN_Fashion-MNIST_2500
train_loss_31=[2.115701362609863, 1.7879307584762574, 1.4952324498494467, 1.265060914993286, 1.1015570993423462, 0.9910386230150858, 0.9198894079526265, 0.8432135221163432, 0.8005357899665833, 0.7655995580355326, 0.7229129311243693, 0.6966289839744568, 0.6704728786945343, 0.6514980785051981, 0.6204178860982259, 0.6196535054842631, 0.5719429988861084, 0.5610518164634705, 0.5628708844184875, 0.5522340693473816, 0.5181823989550273, 0.5022387261390686, 0.49143853346506755, 0.4730520567893982, 0.45396322838465375, 0.4587051323254903, 0.43962639395395914, 0.415267614364624, 0.3912693024476369, 0.3779335996309916, 0.3825831274986267, 0.3576201310157776, 0.35088482745488486, 0.34537577764193217, 0.34948439804712933, 0.3369132613341014, 0.3105340345700582, 0.28804129401842754, 0.2735107443332672, 0.2651301268736521, 0.26481197647253674, 0.2636315842072169, 0.25605449338754016, 0.2623596641222636, 0.21310125724474588, 0.2114095465739568, 0.20271214493115744, 0.19238501489162446, 0.17898249991734821, 0.1781773032148679]
valid_loss_31=[1.9529099435806274, 1.6499783926010132, 1.411308409690857, 1.2203001098632813, 1.1504131002426148, 1.0368723134994506, 0.9791473622322082, 0.9235626707077026, 0.9025027203559876, 0.8887059669494629, 0.8687158308029175, 0.8416149592399598, 0.8103334980010987, 0.805600007534027, 0.7987825574874878, 0.7787080478668212, 0.8191369619369507, 0.772316810131073, 0.7628112325668335, 0.7484024367332458, 0.7155898337364197, 0.697419457435608, 0.7067022423744201, 0.6994534044265747, 0.6586746459007263, 0.668097306728363, 0.6971444673538209, 0.6335903253555298, 0.6524245057106018, 0.6500329732894897, 0.6206314759254455, 0.6204795167446137, 0.6382838747501374, 0.6528866498470306, 0.6576503930091858, 0.6074805846214294, 0.6030231199264526, 0.5793449392318726, 0.6327485628128052, 0.6103732495307922, 0.5800993876457214, 0.6079945745468139, 0.6096610040664673, 0.5638366763591767, 0.559723842382431, 0.5945805821418763, 0.588917829990387, 0.5446437525749207, 0.5357322866916656, 0.5832481064796448]
train_acc_31=[0.29799999968210855, 0.5346666668256124, 0.5993333333333334, 0.620666666507721, 0.6493333330154419, 0.6906666666666667, 0.7060000003178915, 0.7326666661898296, 0.7333333336512248, 0.7580000004768371, 0.7560000004768371, 0.7653333331743876, 0.7666666668256124, 0.7739999996821085, 0.7839999996821085, 0.787333333015442, 0.8099999996821086, 0.8086666669845581, 0.835333333492279, 0.8213333334922791, 0.8433333331743876, 0.8519999996821086, 0.866666666507721, 0.8906666671435038, 0.8920000003178914, 0.8933333334922791, 0.9033333333333333, 0.9166666668256124, 0.9279999995231628, 0.9320000003178914, 0.9286666669845581, 0.9413333338101705, 0.9420000003178914, 0.9393333333333334, 0.9319999995231628, 0.9326666669845581, 0.9499999995231628, 0.9566666669845582, 0.9626666668256124, 0.9613333336512248, 0.9606666666666667, 0.9533333333333334, 0.9553333336512247, 0.9553333336512247, 0.966666666984558, 0.9673333336512248, 0.9720000003178915, 0.9693333333333334, 0.9786666669845581, 0.9746666669845581]
valid_acc_31=[0.4940000009536743, 0.5699999995231628, 0.6000000009536743, 0.6180000004768371, 0.662, 0.6679999995231628, 0.6680000009536743, 0.708, 0.6919999995231628, 0.696, 0.706, 0.696, 0.7160000004768372, 0.7059999990463257, 0.6939999990463257, 0.7359999995231629, 0.7160000009536743, 0.7219999990463257, 0.7280000004768371, 0.7359999995231629, 0.7480000009536744, 0.778, 0.764, 0.7660000004768371, 0.8000000004768372, 0.8079999990463257, 0.7880000004768372, 0.812, 0.7920000009536743, 0.7959999995231628, 0.8159999995231628, 0.8119999990463257, 0.8059999990463257, 0.8040000009536743, 0.7960000004768372, 0.8120000009536743, 0.8020000009536743, 0.8080000004768372, 0.79, 0.8039999990463257, 0.81, 0.79, 0.7899999995231628, 0.8119999995231628, 0.8159999990463257, 0.804, 0.8100000004768372, 0.8139999995231628, 0.8239999990463257, 0.8080000009536743]

# TL-HQCCNN_Fashion-MNIST_2500
train_loss_32=[2.2658599357604983, 1.9949488162994384, 1.7387005681991576, 1.5290573714574178, 1.3444914042154947, 1.2390656401316325, 1.1309413321812947, 1.0414398047129314, 0.9901403290430705, 0.9301640906333923, 0.8858193453152975, 0.8338991384506226, 0.7750413853327434, 0.762031417687734, 0.7528371456464131, 0.7014071586926778, 0.7171564439137776, 0.6956453895568848, 0.6569727689425151, 0.6231011646588643, 0.6207080160776774, 0.589392613252004, 0.5697430497805277, 0.5628800020217896, 0.5813592417240143, 0.5378337080478668, 0.5144807267189025, 0.4902807806332906, 0.4695881611506144, 0.47340602954228717, 0.469965182463328, 0.4452144641081492, 0.4282485942045848, 0.4094595421155294, 0.44728816763559975, 0.4067411823272705, 0.38243848546346026, 0.3968648862838745, 0.3891430364449819, 0.36170336095492045, 0.3948200328350067, 0.38943380284309387, 0.3869154425462087, 0.3547574184735616, 0.3304542321364085, 0.320731525739034, 0.3156041044394175, 0.32228963645299274, 0.28941474135716755, 0.2854518527984619]
valid_loss_32=[2.18700066947937, 1.8354168567657472, 1.627564458847046, 1.439593906402588, 1.2711784133911133, 1.179815312385559, 1.1159439907073974, 1.010499542236328, 1.012148756980896, 0.943527024269104, 0.9138018450737, 0.8570202026367187, 0.8181296191215515, 0.8324577016830444, 0.7843324766159058, 0.7752982873916626, 0.7871581897735596, 0.7268762154579163, 0.7374350385665893, 0.7000681843757629, 0.6944870955944061, 0.6893997550010681, 0.6631598148345947, 0.7472355699539185, 0.6924103927612305, 0.6511053612232208, 0.6590541825294495, 0.632717535495758, 0.6264813232421875, 0.6099586987495422, 0.6047348792552948, 0.6144565091133117, 0.5913197116851807, 0.5868733077049255, 0.6043611388206482, 0.582219759464264, 0.572614712715149, 0.5969864311218261, 0.5678957533836365, 0.5642133920192719, 0.6024320259094238, 0.5679596891403198, 0.5804747557640075, 0.5516162061691284, 0.5370447771549225, 0.5322505512237549, 0.539344985961914, 0.5534575586318969, 0.5142325334548951, 0.5666123497486114]
train_acc_32=[0.19066666674613952, 0.44466666618982953, 0.644, 0.6633333331743876, 0.6633333338101705, 0.6793333328564962, 0.7006666666666667, 0.7206666671435038, 0.7400000001589457, 0.7673333334922791, 0.7573333333333333, 0.7753333338101704, 0.7953333336512248, 0.7926666666666666, 0.7966666671435039, 0.8186666666666667, 0.8073333338101705, 0.8133333338101705, 0.8159999996821086, 0.8300000004768372, 0.845333333492279, 0.8433333336512248, 0.845333333492279, 0.8653333330154419, 0.8546666668256124, 0.8626666663487752, 0.8666666663487752, 0.8780000001589457, 0.8846666671435038, 0.8913333330154419, 0.880666666507721, 0.894666666507721, 0.9066666669845581, 0.8973333334922791, 0.8980000004768371, 0.9119999996821085, 0.9193333338101705, 0.9106666666666666, 0.9179999995231628, 0.924, 0.9093333331743876, 0.9126666669845581, 0.9099999995231628, 0.9146666661898295, 0.9313333331743876, 0.9446666666666667, 0.9373333328564962, 0.9339999998410543, 0.9493333328564961, 0.9466666666666667]
valid_acc_32=[0.21600000047683715, 0.6459999990463257, 0.628, 0.6400000004768371, 0.6900000009536743, 0.6979999990463257, 0.708, 0.7320000009536743, 0.7259999990463257, 0.7339999995231629, 0.7380000004768371, 0.754, 0.762, 0.7439999990463256, 0.7779999990463257, 0.7879999990463257, 0.784, 0.7920000004768372, 0.8060000009536743, 0.796, 0.79, 0.8060000004768372, 0.8120000009536743, 0.7719999995231629, 0.8020000004768372, 0.8299999995231628, 0.8180000004768372, 0.8220000009536743, 0.8060000009536743, 0.812, 0.816, 0.8059999990463257, 0.8179999995231628, 0.8319999995231628, 0.8179999990463257, 0.82, 0.8239999995231628, 0.8220000009536743, 0.8300000009536743, 0.8239999990463257, 0.8000000004768372, 0.8259999990463257, 0.8239999995231628, 0.832, 0.8339999990463257, 0.8300000004768372, 0.832, 0.822, 0.8419999995231628, 0.8240000009536743]

# ST-HQCCNN_Fashion-MNIST_2500
train_loss_33=[1.168074284553528, 0.9639071205457052, 0.7651342207590739, 0.6400508079528808, 0.5702273740768432, 0.5204185630480448, 0.48727294715245567, 0.4635688829421997, 0.4367196116447449, 0.416827917098999, 0.401563796043396, 0.3908648494879405, 0.3815189186731974, 0.36546577405929564, 0.3562682857513428, 0.3485927527745565, 0.3383669476509094, 0.32868540461858115, 0.3254831516742706, 0.3098391668796539, 0.3024017613728841, 0.3005665494600932, 0.2866123263835907, 0.28465412243207294, 0.2679380542437236, 0.26906911047299703, 0.2564832361539205, 0.24533332681655884, 0.23362558897336325, 0.22298606808980306, 0.21953120279312133, 0.21344313549995422, 0.21210334539413453, 0.20670805795987446, 0.19846213018894196, 0.1955981720685959, 0.2084227861960729, 0.19277003661791484, 0.18780939674377442, 0.19287780666351317, 0.19654342118899026, 0.17296942456563313, 0.1693506656487783, 0.1772249583005905, 0.1670476680199305, 0.16272538828849792, 0.1615861575206121, 0.15830921252568564, 0.1742405334711075, 0.1673979263305664]
valid_loss_33=[2.00840740776062, 1.5962749767303466, 1.308646987915039, 1.1541793909072875, 1.0661785926818848, 1.0185198974609375, 1.0021426362991332, 0.9352947959899902, 0.8873350553512573, 0.8661749629974366, 0.8526398258209229, 0.8351882994174957, 0.8130957441329956, 0.8068866734504699, 0.7891002869606019, 0.7696751070022583, 0.7582418661117554, 0.7953877148628234, 0.7568663740158081, 0.7255511384010315, 0.7733931331634522, 0.7296784982681275, 0.7157727899551392, 0.6836038546562195, 0.6830625543594361, 0.6722292039394379, 0.6927378785610199, 0.6261446886062622, 0.6455488629341125, 0.6068942341804504, 0.6223801927566528, 0.6042880806922912, 0.6176903085708618, 0.6023241024017334, 0.6186793556213379, 0.6129945545196533, 0.5898109779357911, 0.5573973641395569, 0.5581288690567017, 0.5950138001441956, 0.5892005491256714, 0.5761771469116211, 0.6070083179473877, 0.5582115620374679, 0.5691822361946106, 0.5544319188594818, 0.5882906675338745, 0.5888665323257446, 0.5760596327781677, 0.54838521027565]
train_acc_33=[0.22199999992052713, 0.47999999968210855, 0.610666666507721, 0.638666666507721, 0.6666666661898295, 0.6859999998410543, 0.7066666666666667, 0.7233333333333334, 0.7406666669845581, 0.7386666669845581, 0.7400000001589457, 0.7520000004768371, 0.7640000001589458, 0.7559999995231629, 0.7699999996821085, 0.7933333333333333, 0.7986666663487753, 0.8193333333333334, 0.8313333328564961, 0.8373333333333334, 0.8519999998410542, 0.8553333330154419, 0.8600000001589457, 0.8580000001589457, 0.882666666507721, 0.8746666668256123, 0.8946666668256124, 0.8893333338101705, 0.908666666507721, 0.9113333331743876, 0.9213333331743876, 0.9200000001589457, 0.9233333334922791, 0.924666666507721, 0.9326666666666666, 0.9386666661898295, 0.9246666666666666, 0.9333333334922791, 0.9373333330154419, 0.9320000003178914, 0.9313333333333333, 0.9473333336512247, 0.9513333331743876, 0.9379999998410543, 0.9493333331743876, 0.9560000001589457, 0.9513333331743876, 0.9553333328564961, 0.9446666661898295, 0.95]
valid_acc_33=[0.36399999952316286, 0.5479999995231628, 0.638, 0.6359999995231629, 0.6720000004768372, 0.6780000009536743, 0.696, 0.6640000009536743, 0.6979999990463257, 0.7000000004768372, 0.702, 0.7219999990463257, 0.6980000004768372, 0.7160000009536743, 0.736, 0.7359999995231629, 0.7579999995231629, 0.7380000009536744, 0.7480000004768371, 0.7620000004768371, 0.7540000009536744, 0.7660000004768371, 0.7659999995231629, 0.7799999990463257, 0.7740000009536743, 0.7819999990463257, 0.7639999995231629, 0.7940000009536743, 0.7939999995231628, 0.8279999995231628, 0.794, 0.8140000004768372, 0.8079999995231628, 0.8039999990463257, 0.8140000009536743, 0.7900000009536743, 0.8100000009536743, 0.8279999990463257, 0.8240000004768372, 0.8200000004768372, 0.7900000004768372, 0.8099999990463257, 0.798, 0.812, 0.8100000004768372, 0.8120000009536743, 0.8060000004768372, 0.7999999990463257, 0.7920000009536743, 0.8120000009536743]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号
plt.rcParams['font.family'] = 'Times New Roman, SimSun'
x = np.arange(0, 50)

width, height = 45, 42 
fig = plt.figure()

fig.set_size_inches(width / 2.54, height / 2.54)

plt.subplot(3, 3, 1)  
loss_1 = train_loss_11
loss_2 = train_loss_12
loss_3 = train_loss_13

loss_4 = valid_loss_11
loss_5 = valid_loss_12
loss_6 = valid_loss_13

line1, = plt.plot(x, loss_1, color='#3483CA',label='HQCCNN_train_loss')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-HQCCNN_train_loss')
line3, = plt.plot(x, loss_3, color='#8AC068',label='ST-HQCCNN_train_loss')
line4, = plt.plot(x, loss_4, color='#3483CA',label='HQCCNN_validation_loss',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-HQCCNN_validation_loss',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='ST-HQCCNN_validation_loss',marker='.')

plt.title("Fashion-MNIST_10000")
plt.legend()
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Loss",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 2.0001, 0.4))
plt.ylim(0, 2)


plt.subplot(3, 3, 4)  
plt.title("Fashion-MNIST_5000")
loss_1 = train_loss_21
loss_2 = train_loss_22
loss_3 = train_loss_23

loss_4 = valid_loss_21
loss_5 = valid_loss_22
loss_6 = valid_loss_23

line1, = plt.plot(x, loss_1, color='#3483CA',label='HQCCNN_train_loss')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-HQCCNN_train_loss')
line3, = plt.plot(x, loss_3, color='#8AC068',label='ST-HQCCNN_train_loss')
line4, = plt.plot(x, loss_4, color='#3483CA',label='HQCCNN_validation_loss',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-HQCCNN_validation_loss',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='ST-HQCCNN_validation_loss',marker='.')

plt.legend()
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Loss",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 2.0001, 0.4))
plt.ylim(0, 2)

plt.subplot(3, 3, 7)  
plt.title("Fashion-MNIST_2500")
loss_1 = train_loss_31
loss_2 = train_loss_32
loss_3 = train_loss_33

loss_4 = valid_loss_31
loss_5 = valid_loss_32
loss_6 = valid_loss_33

line1, = plt.plot(x, loss_1, color='#3483CA',label='HQCCNN_train_loss')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-HQCCNN_train_loss')
line3, = plt.plot(x, loss_3, color='#8AC068',label='ST-HQCCNN_train_loss')
line4, = plt.plot(x, loss_4, color='#3483CA',label='HQCCNN_validation_loss',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-HQCCNN_validation_loss',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='ST-HQCCNN_validation_loss',marker='.')

plt.legend()
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Loss",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 2.0001, 0.4))
plt.ylim(0, 2)

plt.subplot(3, 3, 2)  
plt.title("Fashion-MNIST_10000")
loss_1 = train_acc_11
loss_2 = train_acc_12
loss_3 = train_acc_13

loss_4 = valid_acc_11
loss_5 = valid_acc_12
loss_6 = valid_acc_13

line1, = plt.plot(x, loss_1, color='#3483CA',label='HQCCNN_train_acc')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-HQCCNN_train_acc')
line3, = plt.plot(x, loss_3, color='#8AC068',label='ST-HQCCNN_train_acc')
line4, = plt.plot(x, loss_4, color='#3483CA',label='HQCCNN_validation_acc',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-HQCCNN_validation_acc',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='ST-HQCCNN_validation_acc',marker='.')


plt.legend(loc='lower right')
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Accuracy",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 1.0001, 0.2))
plt.ylim(0, 1)


plt.subplot(3, 3, 5)  
plt.title("Fashion-MNIST_5000")
loss_1 = train_acc_21
loss_2 = train_acc_22
loss_3 = train_acc_23

loss_4 = valid_acc_21
loss_5 = valid_acc_22
loss_6 = valid_acc_23

line1, = plt.plot(x, loss_1, color='#3483CA',label='HQCCNN_train_acc')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-HQCCNN_train_acc')
line3, = plt.plot(x, loss_3, color='#8AC068',label='ST-HQCCNN_train_acc')
line4, = plt.plot(x, loss_4, color='#3483CA',label='HQCCNN_validation_acc',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-HQCCNN_validation_acc',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='ST-HQCCNN_validation_acc',marker='.')

plt.legend()
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Accuracy",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 1.0001, 0.2))
plt.ylim(0, 1)

plt.subplot(3, 3, 8)  
plt.title("Fashion-MNIST_2500")
loss_1 = train_acc_31
loss_2 = train_acc_32
loss_3 = train_acc_33

loss_4 = valid_acc_31
loss_5 = valid_acc_32
loss_6 = valid_acc_33

line1, = plt.plot(x, loss_1, color='#3483CA',label='HQCCNN_train_acc')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-HQCCNN_train_acc')
line3, = plt.plot(x, loss_3, color='#8AC068',label='ST-HQCCNN_train_acc')
line4, = plt.plot(x, loss_4, color='#3483CA',label='HQCCNN_validation_acc',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-HQCCNN_validation_acc',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='ST-HQCCNN_validation_acc',marker='.')

plt.legend()
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Accuracy",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 1.0001, 0.2))
plt.ylim(0, 1)

plt.savefig("./Result/8.png",dpi=600)

plt.show()
