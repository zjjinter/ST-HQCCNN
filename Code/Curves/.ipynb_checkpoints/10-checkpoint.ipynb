# %%
# FC_Fashion-MNIST_2500
train_loss_11=[1.3428478676478068, 0.857766672929128, 0.7527787628968556, 0.7417657804489136, 0.684301309188207, 0.5976574432055155, 0.5440023922920227, 0.5427557644844055, 0.526831576983134, 0.5037918055852254, 0.4888434857527415, 0.45990400075912474, 0.47279730351765953, 0.45014448356628417, 0.44199252939224243, 0.40940767884254453, 0.37815249276161195, 0.39860418558120725, 0.4115937738418579, 0.3535199695428212, 0.43387153641382853, 0.43514907654126483, 0.348199036359787, 0.35070898008346557, 0.3226959443092346, 0.3416963811715444, 0.3674225212732951, 0.2919560821056366, 0.324480167388916, 0.43653265285491943, 0.35255748669306436, 0.31165898847579954, 0.31315234863758085, 0.2919762709935506, 0.3317793730099996, 0.25401078653335574, 0.24497440965970357, 0.31993230171998344, 0.29941153240203855, 0.272879607518514, 0.3019120368162791, 0.29788202794392904, 0.27373333160082497, 0.3337624552249908, 0.2694594744245211, 0.28776471090316774, 0.2545907136599223, 0.2500113227367401, 0.2372529859940211, 0.2447717044353485]
valid_loss_11=[0.9297502374649048, 0.8035341830253601, 1.0720644216537476, 0.6468823709487915, 0.7282526783943176, 0.7245688886642456, 0.6909481530189514, 0.6085181851387024, 0.6642706298828125, 0.809588442325592, 0.6028082818984986, 0.6507291922569275, 0.6401910943984985, 0.6475766711235046, 0.661767276763916, 0.6852857027053832, 0.7347301771640777, 0.7863171334266663, 0.6786959857940674, 0.7612658205032349, 0.8464387574195862, 0.685249593257904, 0.650051887512207, 0.7401409525871276, 0.6881123495101928, 0.7341529929637909, 0.8139789514541625, 0.7127711529731751, 0.8775732140541077, 1.0722134575843811, 0.8533983602523804, 0.7099793195724488, 0.9175615158081055, 0.9504974699020385, 0.8357031614780426, 0.8251072549819947, 1.0379917440414428, 0.968024471282959, 0.7909857320785523, 1.0875971188545228, 1.0979081587791444, 0.8871619644165039, 0.9207208108901977, 0.7708568000793456, 0.7619235296249389, 0.9092558803558349, 0.7998550968170166, 0.8874633836746216, 1.1025329666137695, 1.0866772594451903]
train_acc_11=[0.5206666663487752, 0.7106666663487752, 0.742666666507721, 0.7473333333333333, 0.7520000001589457, 0.7953333338101705, 0.814, 0.8086666665077209, 0.8213333333333334, 0.8273333338101705, 0.8219999996821086, 0.841333333492279, 0.8380000001589457, 0.8379999996821086, 0.8393333331743876, 0.8513333330154419, 0.862666666507721, 0.8546666661898296, 0.8560000004768371, 0.876666666507721, 0.8393333333333334, 0.832, 0.8819999998410543, 0.8673333338101705, 0.8833333333333333, 0.8800000001589457, 0.8593333338101705, 0.8933333336512248, 0.8800000001589457, 0.8426666663487752, 0.8733333330154419, 0.8726666663487752, 0.8826666669845581, 0.8886666661898295, 0.8799999995231629, 0.9020000001589458, 0.9173333328564962, 0.8799999995231629, 0.888, 0.9013333331743876, 0.8879999998410543, 0.8860000004768371, 0.9006666661898295, 0.868666666507721, 0.9006666669845581, 0.898666666507721, 0.9086666666666666, 0.9093333336512248, 0.9093333331743876, 0.912666666507721]
valid_acc_11=[0.7120000004768372, 0.7399999995231629, 0.6699999995231628, 0.7859999995231628, 0.7319999990463257, 0.7119999990463257, 0.7699999990463257, 0.7900000009536743, 0.7339999995231629, 0.7199999995231628, 0.7819999990463257, 0.7700000004768371, 0.776, 0.7759999995231628, 0.7759999995231628, 0.764, 0.7600000004768371, 0.762, 0.7579999995231629, 0.7599999995231629, 0.7160000009536743, 0.7580000004768371, 0.7700000004768371, 0.75, 0.7679999990463257, 0.762, 0.728, 0.7799999995231628, 0.7279999995231629, 0.6939999990463257, 0.7540000009536744, 0.784, 0.734, 0.7579999990463256, 0.7520000004768371, 0.7639999990463257, 0.7259999995231629, 0.7439999995231629, 0.7739999995231629, 0.7020000004768372, 0.7339999995231629, 0.7399999995231629, 0.7500000004768371, 0.7719999995231629, 0.7959999995231628, 0.7400000009536744, 0.7539999990463256, 0.7500000004768371, 0.7320000009536743, 0.7319999995231629]

# CNN-1D_Fashion-MNIST_2500
train_loss_12=[1.8022426907221476, 1.1174694684346518, 0.8300161852836608, 0.750476274172465, 0.6257686193784078, 0.5407364951769511, 0.5320256603558858, 0.482415047566096, 0.4684265295664469, 0.41604763054847715, 0.37963552498817443, 0.3841887538433075, 0.36439832353591917, 0.32484128244717914, 0.27562140345573427, 0.35840747292836506, 0.2998422077496847, 0.2697362574736277, 0.22502560929457346, 0.26803872390588124, 0.29356508986155194, 0.2430451993147532, 0.23090541903177897, 0.23639389765262603, 0.22694063079357146, 0.18767811326185863, 0.23885104922453562, 0.18005096552769342, 0.1543734289209048, 0.1939843351840973, 0.20685358428955078, 0.19704095248381298, 0.15179368178049724, 0.16002286074558894, 0.15936051789919536, 0.16410869789123536, 0.1847025386095047, 0.2488218923608462, 0.3564791467189789, 0.21057790225744247, 0.1689346677660942, 0.16270582910378775, 0.15310003340244294, 0.18298454183340074, 0.10648625925183296, 0.11423010836044947, 0.11888879118363063, 0.10893517108758291, 0.1232820215622584, 0.062115215986967086]
valid_loss_12=[1.2455215768814087, 1.0015673151016236, 0.722551194190979, 0.7103831033706665, 0.656562834739685, 0.6823975105285645, 0.7324272003173828, 0.6571204214096069, 0.7703754472732544, 0.8013595957756042, 0.6791675577163696, 0.6632936143875122, 0.6847634577751159, 0.6912806625366211, 0.9654492616653443, 0.860216775894165, 0.7455512475967407, 0.6496010074615478, 0.7345859179496765, 1.0070950379371644, 0.8684577622413635, 0.7519993462562561, 0.7686390898227692, 0.9100977287292481, 0.7728087234497071, 1.0074505419731141, 0.7906312127113342, 0.8403758187294006, 0.7864224300384521, 0.8359308967590332, 0.9526312026977539, 0.785785361289978, 0.9346883546113968, 0.9619401376247406, 0.9351368999481201, 1.0005136833190917, 0.99540927028656, 1.2165724391937256, 0.9295549993515014, 0.9785210161209107, 1.0257973818778992, 0.8473133840560914, 1.4242758026123048, 0.9590256762504578, 0.9127784385681152, 0.9044544115066528, 0.9862321853637696, 1.109965497970581, 0.9763297414779664, 1.0151090354919434]
train_acc_12=[0.357333333492279, 0.5899999995231628, 0.724, 0.7559999995231629, 0.798, 0.8253333331743876, 0.8166666663487753, 0.8393333330154419, 0.8393333338101705, 0.8533333331743876, 0.8713333338101705, 0.859333333492279, 0.8746666671435038, 0.890666666507721, 0.9040000003178914, 0.8713333331743877, 0.9019999998410543, 0.9033333331743876, 0.926, 0.9033333336512248, 0.8886666668256124, 0.9146666669845581, 0.9166666661898295, 0.9199999995231628, 0.92, 0.9306666669845581, 0.9179999995231628, 0.9393333333333334, 0.95, 0.9319999998410543, 0.9226666669845581, 0.9313333336512247, 0.9499999998410543, 0.9433333336512247, 0.9439999995231628, 0.9426666661898295, 0.9399999995231628, 0.9166666666666666, 0.8853333328564962, 0.9380000003178914, 0.9426666669845581, 0.9493333328564961, 0.9500000003178914, 0.9400000003178914, 0.966, 0.962666666984558, 0.9626666661898295, 0.9626666666666667, 0.9566666669845582, 0.982]
valid_acc_12=[0.5800000004768372, 0.6219999995231629, 0.778, 0.7719999995231629, 0.7760000004768371, 0.7739999995231629, 0.7520000009536744, 0.79, 0.7500000004768371, 0.7680000009536743, 0.7899999995231628, 0.7820000009536743, 0.7979999990463257, 0.7920000004768372, 0.7480000004768371, 0.7540000009536744, 0.7939999990463257, 0.8039999995231628, 0.7780000009536743, 0.7460000009536744, 0.7800000009536743, 0.7979999990463257, 0.7919999990463257, 0.7859999990463257, 0.808, 0.7720000004768371, 0.7880000004768372, 0.7899999990463257, 0.796, 0.8040000004768372, 0.7880000004768372, 0.8019999990463257, 0.7899999995231628, 0.7900000004768372, 0.79, 0.7960000009536743, 0.792, 0.7439999990463256, 0.7780000009536743, 0.7700000009536743, 0.79, 0.8100000004768372, 0.7480000004768371, 0.7560000004768371, 0.7919999990463257, 0.7900000004768372, 0.7779999995231628, 0.7819999995231628, 0.7960000004768372, 0.784]

# HQCCNN_Fashion-MNIST_2500
train_loss_13=[2.115701362609863, 1.7879307584762574, 1.4952324498494467, 1.265060914993286, 1.1015570993423462, 0.9910386230150858, 0.9198894079526265, 0.8432135221163432, 0.8005357899665833, 0.7655995580355326, 0.7229129311243693, 0.6966289839744568, 0.6704728786945343, 0.6514980785051981, 0.6204178860982259, 0.6196535054842631, 0.5719429988861084, 0.5610518164634705, 0.5628708844184875, 0.5522340693473816, 0.5181823989550273, 0.5022387261390686, 0.49143853346506755, 0.4730520567893982, 0.45396322838465375, 0.4587051323254903, 0.43962639395395914, 0.415267614364624, 0.3912693024476369, 0.3779335996309916, 0.3825831274986267, 0.3576201310157776, 0.35088482745488486, 0.34537577764193217, 0.34948439804712933, 0.3369132613341014, 0.3105340345700582, 0.28804129401842754, 0.2735107443332672, 0.2651301268736521, 0.26481197647253674, 0.2636315842072169, 0.25605449338754016, 0.2623596641222636, 0.21310125724474588, 0.2114095465739568, 0.20271214493115744, 0.19238501489162446, 0.17898249991734821, 0.1781773032148679]
valid_loss_13=[1.9529099435806274, 1.6499783926010132, 1.411308409690857, 1.2203001098632813, 1.1504131002426148, 1.0368723134994506, 0.9791473622322082, 0.9235626707077026, 0.9025027203559876, 0.8887059669494629, 0.8687158308029175, 0.8416149592399598, 0.8103334980010987, 0.805600007534027, 0.7987825574874878, 0.7787080478668212, 0.8191369619369507, 0.772316810131073, 0.7628112325668335, 0.7484024367332458, 0.7155898337364197, 0.697419457435608, 0.7067022423744201, 0.6994534044265747, 0.6586746459007263, 0.668097306728363, 0.6971444673538209, 0.6335903253555298, 0.6524245057106018, 0.6500329732894897, 0.6206314759254455, 0.6204795167446137, 0.6382838747501374, 0.6528866498470306, 0.6576503930091858, 0.6074805846214294, 0.6030231199264526, 0.5793449392318726, 0.6327485628128052, 0.6103732495307922, 0.5800993876457214, 0.6079945745468139, 0.6096610040664673, 0.5638366763591767, 0.559723842382431, 0.5945805821418763, 0.588917829990387, 0.5446437525749207, 0.5357322866916656, 0.5832481064796448]
train_acc_13=[0.29799999968210855, 0.5346666668256124, 0.5993333333333334, 0.620666666507721, 0.6493333330154419, 0.6906666666666667, 0.7060000003178915, 0.7326666661898296, 0.7333333336512248, 0.7580000004768371, 0.7560000004768371, 0.7653333331743876, 0.7666666668256124, 0.7739999996821085, 0.7839999996821085, 0.787333333015442, 0.8099999996821086, 0.8086666669845581, 0.835333333492279, 0.8213333334922791, 0.8433333331743876, 0.8519999996821086, 0.866666666507721, 0.8906666671435038, 0.8920000003178914, 0.8933333334922791, 0.9033333333333333, 0.9166666668256124, 0.9279999995231628, 0.9320000003178914, 0.9286666669845581, 0.9413333338101705, 0.9420000003178914, 0.9393333333333334, 0.9319999995231628, 0.9326666669845581, 0.9499999995231628, 0.9566666669845582, 0.9626666668256124, 0.9613333336512248, 0.9606666666666667, 0.9533333333333334, 0.9553333336512247, 0.9553333336512247, 0.966666666984558, 0.9673333336512248, 0.9720000003178915, 0.9693333333333334, 0.9786666669845581, 0.9746666669845581]
valid_acc_13=[0.4940000009536743, 0.5699999995231628, 0.6000000009536743, 0.6180000004768371, 0.662, 0.6679999995231628, 0.6680000009536743, 0.708, 0.6919999995231628, 0.696, 0.706, 0.696, 0.7160000004768372, 0.7059999990463257, 0.6939999990463257, 0.7359999995231629, 0.7160000009536743, 0.7219999990463257, 0.7280000004768371, 0.7359999995231629, 0.7480000009536744, 0.778, 0.764, 0.7660000004768371, 0.8000000004768372, 0.8079999990463257, 0.7880000004768372, 0.812, 0.7920000009536743, 0.7959999995231628, 0.8159999995231628, 0.8119999990463257, 0.8059999990463257, 0.8040000009536743, 0.7960000004768372, 0.8120000009536743, 0.8020000009536743, 0.8080000004768372, 0.79, 0.8039999990463257, 0.81, 0.79, 0.7899999995231628, 0.8119999995231628, 0.8159999990463257, 0.804, 0.8100000004768372, 0.8139999995231628, 0.8239999990463257, 0.8080000009536743]

# %%
# TL-FC_Fashion-MNIST_2500
train_loss_21=[1.5582816518147786, 1.105381371498108, 0.8897667943636577, 0.8147703145345052, 0.706177887916565, 0.7137523571650187, 0.6803105190594991, 0.6834058111508687, 0.6606663702329, 0.5788368512789408, 0.6931229098637899, 0.6802585666974386, 0.5918567221562068, 0.5128043805758158, 0.6054074950218201, 0.4834526093800863, 0.5396242639223735, 0.5240195328394572, 0.5567492434183756, 0.5031952562332154, 0.5271301790475845, 0.5692792234420776, 0.46165194511413576, 0.48041047286987304, 0.5449240413506826, 0.4871338547070821, 0.4508413790067037, 0.5418021952311198, 0.44304443200429283, 0.46030053877830507, 0.593068774064382, 0.5003224932352702, 0.4556965888341268, 0.4633928887049357, 0.5404294567108154, 0.455021836121877, 0.455686696211497, 0.5325027948220571, 0.4061770084698995, 0.4794119036992391, 0.43257680185635883, 0.4604634325504303, 0.42141566236813865, 0.449277718146642, 0.5023640332221985, 0.44540866899490356, 0.3877275605201721, 0.49034691747029624, 0.42786968580881757, 0.4140982979138692]
valid_loss_21=[1.3661668014526367, 0.9050440778732299, 0.8215049180984497, 0.6966568531990052, 0.7477307667732239, 0.6766620101928711, 0.8311642618179321, 0.7559553384780884, 0.7731187820434571, 0.7672474703788758, 0.8231580553054809, 0.9109808659553528, 0.6877633357048034, 0.9905365414619446, 0.6740567789077759, 0.8385121278762817, 0.7590688180923462, 0.6937536163330078, 0.749144721031189, 0.7077644166946411, 0.6976627233028412, 0.6460162167549133, 0.6876392283439636, 0.787181706905365, 0.960517237663269, 0.7469990420341491, 1.0814508781433105, 0.8309260096549987, 0.7677268466949463, 0.8034921598434448, 0.9178062410354614, 0.7312135066986084, 0.7184234788417816, 0.7654306421279907, 0.8065546140670776, 0.7425336484909058, 0.8779755249023438, 0.8043438086509704, 0.8315325741767883, 0.8885485124588013, 0.7191963291168213, 0.7949827690124511, 0.7520359208583832, 0.7791556138992309, 0.7999925403594971, 0.7392194752693176, 0.9239657764434814, 0.8863092608451844, 0.8779028482437133, 0.7499388990402222]
train_acc_21=[0.4639999998410543, 0.6173333330154419, 0.6593333334922791, 0.6999999995231628, 0.746, 0.7320000001589457, 0.7453333338101705, 0.7553333338101705, 0.7420000003178915, 0.7799999996821085, 0.7513333330154419, 0.7493333336512248, 0.778666666507721, 0.806, 0.7719999998410543, 0.8266666666666667, 0.8053333333333333, 0.8139999998410543, 0.7793333334922791, 0.8179999995231628, 0.8020000003178914, 0.7839999995231628, 0.8240000004768372, 0.8093333331743876, 0.7926666668256124, 0.8380000003178915, 0.8360000004768372, 0.7973333331743876, 0.8400000004768372, 0.8300000004768372, 0.7806666663487752, 0.8100000004768372, 0.8306666661898295, 0.8299999996821086, 0.798666666507721, 0.8226666666666667, 0.8359999998410543, 0.8026666668256124, 0.8486666668256124, 0.8159999998410543, 0.8353333338101705, 0.8219999995231628, 0.8453333338101705, 0.8313333328564961, 0.8073333330154419, 0.8373333330154419, 0.861333333492279, 0.8126666669845581, 0.8399999998410543, 0.8433333331743876]
valid_acc_21=[0.5379999990463257, 0.6500000009536743, 0.6560000009536743, 0.7339999995231629, 0.7420000009536744, 0.7540000004768371, 0.6939999990463257, 0.7319999995231629, 0.726, 0.7239999995231629, 0.6760000004768372, 0.7000000004768372, 0.7639999995231629, 0.672, 0.7659999995231629, 0.7219999990463257, 0.73, 0.7660000009536743, 0.7619999990463256, 0.7499999990463256, 0.7540000009536744, 0.7660000004768371, 0.7699999990463257, 0.7220000004768372, 0.6900000004768372, 0.7320000009536743, 0.6559999990463257, 0.7439999990463256, 0.7419999990463256, 0.7139999990463257, 0.6980000004768372, 0.7520000009536744, 0.7599999990463256, 0.7519999990463256, 0.7140000004768372, 0.7560000004768371, 0.7360000009536743, 0.7360000009536743, 0.742, 0.732, 0.7480000009536744, 0.7359999995231629, 0.7500000004768371, 0.7080000004768372, 0.7219999990463257, 0.7660000004768371, 0.7319999990463257, 0.7079999990463257, 0.7180000009536743, 0.7499999995231629]

# TL-CNN-1D_Fashion-MNIST_2500
train_loss_22=[2.176394223531087, 2.0043777017593385, 1.9307916889190673, 1.868048976580302, 1.8125815814336141, 1.6561002670923868, 1.593622021039327, 1.5370731334686278, 1.4467872091929117, 1.4256693855921427, 1.2822972857157389, 1.1064068581263224, 1.0335251398086547, 0.9878285204569499, 0.9429410676956177, 0.8718520533243815, 0.874933139483134, 0.8782258041699728, 0.8023386980692545, 0.7434456427892049, 0.7120951846440633, 0.6582853269577026, 0.6892587835788727, 0.7584339475631714, 0.6540561964511872, 0.654149941444397, 0.6314557967185974, 0.6012356052398682, 0.6376334957281748, 0.528132247765859, 0.5307242048581441, 0.561732278029124, 0.5572074263890584, 0.5281193064053853, 0.5102582314809163, 0.4739622639020284, 0.4500837213198344, 0.47148581107457477, 0.43729957882563275, 0.4004171625773112, 0.4203778793811798, 0.43929258624712625, 0.4001352683703105, 0.3521358165740967, 0.37868005855878195, 0.49980044571558635, 0.4007559116681417, 0.393183730840683, 0.3315772852897644, 0.34574845417340594]
valid_loss_22=[2.1542445850372314, 1.9585769863128661, 1.8796340198516845, 1.9206603317260742, 1.6897452268600464, 1.6059741640090943, 1.5496281127929687, 1.506411039352417, 1.4212778558731078, 1.389760866165161, 1.1306184854507446, 1.0914931144714355, 1.170360279083252, 0.9114025897979736, 0.9067953481674195, 0.842015308380127, 0.8233463611602784, 0.8984529275894165, 0.784154525756836, 0.7436122722625732, 0.7575397849082947, 0.742541690826416, 0.7377354116439819, 0.6854343771934509, 0.6831872501373291, 0.7203168988227844, 0.6769007091522217, 0.7296867389678955, 0.7648875522613525, 0.6856648335456849, 0.6876415700912476, 0.8534185862541199, 0.7087487115859985, 0.6478794760704041, 0.6801712000370026, 0.6962887716293334, 0.6691825189590455, 0.707335452079773, 0.7777871088981628, 0.6603888936042785, 0.6784239001274109, 0.7375164451599121, 0.7451543536186218, 0.7415231885910034, 0.7865009400844574, 0.7578913226127625, 0.7970601615905761, 0.7950485253334045, 0.7111055812835694, 0.7177607612609863]
train_acc_22=[0.10000000001986821, 0.18933333333333333, 0.22200000007947285, 0.2453333331743876, 0.3133333331743876, 0.3306666669050852, 0.334, 0.36400000007947286, 0.428, 0.4433333330154419, 0.5040000001589457, 0.556, 0.6193333330154419, 0.6086666666666667, 0.6373333336512248, 0.6613333336512248, 0.676, 0.6420000001589458, 0.6813333334922791, 0.6999999996821086, 0.7293333338101705, 0.7393333336512248, 0.7346666671435038, 0.7106666671435038, 0.7573333333333333, 0.7493333336512248, 0.756, 0.7720000004768371, 0.7626666668256123, 0.8013333333333333, 0.8059999996821086, 0.7999999995231628, 0.7893333334922791, 0.8080000001589457, 0.8233333338101705, 0.8300000004768372, 0.8340000001589457, 0.8306666661898295, 0.8393333331743876, 0.8580000004768371, 0.8460000001589457, 0.8313333338101705, 0.8473333338101705, 0.8779999998410543, 0.8646666671435038, 0.8133333330154419, 0.8466666666666667, 0.8793333336512248, 0.8799999998410543, 0.878666666507721]
valid_acc_22=[0.10000000023841858, 0.22200000047683716, 0.23600000047683717, 0.2580000001192093, 0.31999999976158144, 0.3260000002384186, 0.32799999952316283, 0.398, 0.44199999976158144, 0.4359999995231628, 0.5240000009536743, 0.542, 0.552, 0.6280000004768371, 0.6280000004768371, 0.6539999990463257, 0.6680000004768372, 0.6280000009536744, 0.6639999995231628, 0.694, 0.6799999990463257, 0.7100000009536743, 0.688, 0.7060000004768372, 0.7040000004768372, 0.7039999990463257, 0.716, 0.718, 0.7140000009536743, 0.7020000009536743, 0.746, 0.6759999995231628, 0.7159999990463257, 0.7539999995231629, 0.7239999995231629, 0.7280000009536743, 0.7680000009536743, 0.734, 0.72, 0.77, 0.7579999995231629, 0.7379999990463257, 0.7400000009536744, 0.7600000004768371, 0.7440000009536744, 0.7480000009536744, 0.74, 0.7459999990463256, 0.7819999990463257, 0.7679999995231629]

# TL-HQCCNN_Fashion-MNIST_2500
train_loss_23=[2.2658599357604983, 1.9949488162994384, 1.7387005681991576, 1.5290573714574178, 1.3444914042154947, 1.2390656401316325, 1.1309413321812947, 1.0414398047129314, 0.9901403290430705, 0.9301640906333923, 0.8858193453152975, 0.8338991384506226, 0.7750413853327434, 0.762031417687734, 0.7528371456464131, 0.7014071586926778, 0.7171564439137776, 0.6956453895568848, 0.6569727689425151, 0.6231011646588643, 0.6207080160776774, 0.589392613252004, 0.5697430497805277, 0.5628800020217896, 0.5813592417240143, 0.5378337080478668, 0.5144807267189025, 0.4902807806332906, 0.4695881611506144, 0.47340602954228717, 0.469965182463328, 0.4452144641081492, 0.4282485942045848, 0.4094595421155294, 0.44728816763559975, 0.4067411823272705, 0.38243848546346026, 0.3968648862838745, 0.3891430364449819, 0.36170336095492045, 0.3948200328350067, 0.38943380284309387, 0.3869154425462087, 0.3547574184735616, 0.3304542321364085, 0.320731525739034, 0.3156041044394175, 0.32228963645299274, 0.28941474135716755, 0.2854518527984619]
valid_loss_23=[2.18700066947937, 1.8354168567657472, 1.627564458847046, 1.439593906402588, 1.2711784133911133, 1.179815312385559, 1.1159439907073974, 1.010499542236328, 1.012148756980896, 0.943527024269104, 0.9138018450737, 0.8570202026367187, 0.8181296191215515, 0.8324577016830444, 0.7843324766159058, 0.7752982873916626, 0.7871581897735596, 0.7268762154579163, 0.7374350385665893, 0.7000681843757629, 0.6944870955944061, 0.6893997550010681, 0.6631598148345947, 0.7472355699539185, 0.6924103927612305, 0.6511053612232208, 0.6590541825294495, 0.632717535495758, 0.6264813232421875, 0.6099586987495422, 0.6047348792552948, 0.6144565091133117, 0.5913197116851807, 0.5868733077049255, 0.6043611388206482, 0.582219759464264, 0.572614712715149, 0.5969864311218261, 0.5678957533836365, 0.5642133920192719, 0.6024320259094238, 0.5679596891403198, 0.5804747557640075, 0.5516162061691284, 0.5370447771549225, 0.5322505512237549, 0.539344985961914, 0.5534575586318969, 0.5142325334548951, 0.5666123497486114]
train_acc_23=[0.19066666674613952, 0.44466666618982953, 0.644, 0.6633333331743876, 0.6633333338101705, 0.6793333328564962, 0.7006666666666667, 0.7206666671435038, 0.7400000001589457, 0.7673333334922791, 0.7573333333333333, 0.7753333338101704, 0.7953333336512248, 0.7926666666666666, 0.7966666671435039, 0.8186666666666667, 0.8073333338101705, 0.8133333338101705, 0.8159999996821086, 0.8300000004768372, 0.845333333492279, 0.8433333336512248, 0.845333333492279, 0.8653333330154419, 0.8546666668256124, 0.8626666663487752, 0.8666666663487752, 0.8780000001589457, 0.8846666671435038, 0.8913333330154419, 0.880666666507721, 0.894666666507721, 0.9066666669845581, 0.8973333334922791, 0.8980000004768371, 0.9119999996821085, 0.9193333338101705, 0.9106666666666666, 0.9179999995231628, 0.924, 0.9093333331743876, 0.9126666669845581, 0.9099999995231628, 0.9146666661898295, 0.9313333331743876, 0.9446666666666667, 0.9373333328564962, 0.9339999998410543, 0.9493333328564961, 0.9466666666666667]
valid_acc_23=[0.21600000047683715, 0.6459999990463257, 0.628, 0.6400000004768371, 0.6900000009536743, 0.6979999990463257, 0.708, 0.7320000009536743, 0.7259999990463257, 0.7339999995231629, 0.7380000004768371, 0.754, 0.762, 0.7439999990463256, 0.7779999990463257, 0.7879999990463257, 0.784, 0.7920000004768372, 0.8060000009536743, 0.796, 0.79, 0.8060000004768372, 0.8120000009536743, 0.7719999995231629, 0.8020000004768372, 0.8299999995231628, 0.8180000004768372, 0.8220000009536743, 0.8060000009536743, 0.812, 0.816, 0.8059999990463257, 0.8179999995231628, 0.8319999995231628, 0.8179999990463257, 0.82, 0.8239999995231628, 0.8220000009536743, 0.8300000009536743, 0.8239999990463257, 0.8000000004768372, 0.8259999990463257, 0.8239999995231628, 0.832, 0.8339999990463257, 0.8300000004768372, 0.832, 0.822, 0.8419999995231628, 0.8240000009536743]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号
plt.rcParams['font.family'] = 'Times New Roman, SimSun'
x = np.arange(0, 50)

width, height = 45, 27 
fig = plt.figure()

fig.set_size_inches(width / 2.54, height / 2.54)

plt.subplot(2, 3, 1)  # fig是一个二行三列布局的图，且现在画的是（1，1）图
loss_1 = train_loss_11
loss_2 = train_loss_12
loss_3 = train_loss_13

loss_4 = valid_loss_11
loss_5 = valid_loss_12
loss_6 = valid_loss_13

line1, = plt.plot(x, loss_1, color='#3483CA',label='FC_train_loss')
line2, = plt.plot(x, loss_2, color='#F18B53',label='CNN_1D_train_loss')
line3, = plt.plot(x, loss_3, color='#8AC068',label='HQCCNN_train_loss')
line4, = plt.plot(x, loss_4, color='#3483CA',label='FC_validation_loss',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='CNN_1D_validation_loss',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='HQCCNN_validation_loss',marker='.')

plt.title("Fashion-MNIST_2500")
plt.legend(loc='upper right')
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Loss",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 2.0001, 0.4))
plt.ylim(0, 2)


plt.subplot(2, 3, 2)  # 当前图是（1，2）图
plt.title("Fashion-MNIST_2500")
loss_1 = train_loss_21
loss_2 = train_loss_22
loss_3 = train_loss_23

loss_4 = valid_loss_21
loss_5 = valid_loss_22
loss_6 = valid_loss_23

line1, = plt.plot(x, loss_1, color='#3483CA',label='TL-FC_train_loss')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-CNN_1D_train_loss')
line3, = plt.plot(x, loss_3, color='#8AC068',label='TL-HQCCNN_train_loss')
line4, = plt.plot(x, loss_4, color='#3483CA',label='TL-FC_validation_loss',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-CNN_1D_validation_loss',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='TL-HQCCNN_validation_loss',marker='.')

plt.legend()
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Loss",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 2.0001, 0.4))
plt.ylim(0, 2)



plt.subplot(2, 3, 4)  # 当前图变为（2，1）图
plt.title("Fashion-MNIST_2500")
loss_1 = train_acc_11
loss_2 = train_acc_12
loss_3 = train_acc_13

loss_4 = valid_acc_11
loss_5 = valid_acc_12
loss_6 = valid_acc_13

line1, = plt.plot(x, loss_1, color='#3483CA',label='FC_train_acc')
line2, = plt.plot(x, loss_2, color='#F18B53',label='CNN_1D_train_acc')
line3, = plt.plot(x, loss_3, color='#8AC068',label='HQCCNN_train_acc')
line4, = plt.plot(x, loss_4, color='#3483CA',label='FC_validation_acc',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='CNN_1D_validation_acc',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='HQCCNN_validation_acc',marker='.')


plt.legend(loc='lower right')
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Accuracy",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 1.0001, 0.2))
plt.ylim(0, 1)


plt.subplot(2, 3, 5)  # 当前图变为（2，2）图
plt.title("Fashion-MNIST_2500")
loss_1 = train_acc_21
loss_2 = train_acc_22
loss_3 = train_acc_23

loss_4 = valid_acc_21
loss_5 = valid_acc_22
loss_6 = valid_acc_23

line1, = plt.plot(x, loss_1, color='#3483CA',label='TL-FC_train_acc')
line2, = plt.plot(x, loss_2, color='#F18B53',label='TL-CNN_1D_train_acc')
line3, = plt.plot(x, loss_3, color='#8AC068',label='TL-HQCCNN_train_acc')
line4, = plt.plot(x, loss_4, color='#3483CA',label='TL-FC_validation_acc',marker='.')
line5, = plt.plot(x, loss_5, color='#F18B53',label='TL-CNN_1D_validation_acc',marker='.')
line6, = plt.plot(x, loss_6, color='#8AC068',label='TL-HQCCNN_validation_acc',marker='.')

plt.legend()
plt.xlabel("Epochs",fontsize=12)
plt.ylabel("Accuracy",fontsize=12)

plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 1.0001, 0.2))
plt.ylim(0, 1)

plt.savefig("./Result/10.png",dpi=600)

plt.show()
